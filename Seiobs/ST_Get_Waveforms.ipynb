# %% [markdown]
# This notebook reads info from a given catalog and saves the specified waveform traces as SAC files. Original author: Axel Wang/Xiaohan Song. Significant modifications by Emmanuel, though the unefficient cata structure has not yet been fixed.

# %% [markdown]
# <span style="color:red; font-weight:bold;">CHANGE THINGS IN 2 AREAS:</span><br>
# <span style="color:red; font-weight:bold;">1. File/directory naming under Setup</span><br>
# <span style="color:red; font-weight:bold;">2. Study area and station under Process --> Download info</span>

# %% [markdown]
# # Import

# %%
from obspy import read, read_inventory
from obspy.geodetics import degrees2kilometers
from obspy.signal import rotate
import math
from scipy.io import savemat
from os.path import join as pjoin
from obspy import Trace
from obspy import Stream
import numpy as np
import glob
from obspy.signal import filter
from obspy.clients.fdsn import Client
from obspy.core.event import Origin
from obspy.geodetics import gps2dist_azimuth, kilometer2degrees
from obspy.taup import TauPyModel
from obspy.io.sac.sactrace import SACTrace
from obspy import read_inventory, UTCDateTime
from obspy import read
from obspy.signal.tf_misfit import plot_tfr
from obspy.signal.cross_correlation import correlate
import numpy as np
import matplotlib.pyplot as plt
from obspy.geodetics.base import gps2dist_azimuth
import csv
import os
import pathlib
from matplotlib.path import Path
import sympy as sp
from scipy.optimize import curve_fit
from scipy import interpolate

# %% [markdown]
# # Setup

# %%
# TOGGLE
name = 'ST_Final.txt'
direct = 'ST_Raw_Data/'

# %%
# Catalog to read
catalog = 'PROVIDED.cata'

# Client
client = Client("IRIS")
# Earth model
# model = TauPyModel(model="iasp91")
model = TauPyModel(model='/Users/emmanuelzheng/Downloads/Synthetics/Seisyn/Tibetan_model.npz')

# Folder to store data
directory = '/Users/emmanuelzheng/Downloads/Synthetics/Seiobs/'
# Directory
raw_directory = directory+direct # Directory to download raw data
# Create directory if it doesn't exist
os.makedirs(raw_directory, exist_ok=True)

# Ensure directory is empty
paths = pathlib.Path(raw_directory).glob('*.SAC') # Delete all existing SAC files in raw data directory
for path in paths:
    path.unlink()  # Remove each SAC file

# %% [markdown]
# # Process

# %% [markdown]
# ## Prep cata

# %%
# Initialize a 1x1 matrix to store earthquake catalog data
cata = np.mat([1])

# Open the catalog file 'PROVIDED.cata' for reading
with open(catalog) as fc:
    # Read all lines from the file into a list
    reader = fc.readlines()
    
    # Loop through each line in the catalog file
    for row in reader:
        # Split the line into individual values (space-separated)
        lst = row.split()
        
        # Line has fewer than 8 columns (incomplete data)
        if len(lst) < 8:
            # Check if this is the first valid entry
            if len(cata.transpose()) == 1:
                # Create first row of catalog with earthquake data
                # lst[0]+'T'+lst[1]: Combine date and time into ISO format
                # lst[3]: longitude
                # lst[4]: latitude  
                # (float(lst[5])+float(lst[5]))/2: depth (duplicated value divided by 2)
                # lst[2]: magnitude
                # lst[6]: depth error
                # lst[5]: depth again
                # lst[-1]: star (if exist) or random
                cata = np.mat([[lst[0]+'T'+lst[1], float(lst[3]), float(lst[4]), float(lst[5]), float(lst[2]), float(lst[6]), float(lst[5]), lst[-1]]])
            else:
                # Append new row to existing catalog matrix
                cata = np.r_[cata, np.mat([[lst[0]+'T'+lst[1], float(lst[3]), float(lst[4]), float(lst[5]), float(lst[2]), float(lst[6]), float(lst[5]), lst[-1]]])]
        
        # Line has 8 or more columns (complete data)
        else:
            # Check if this is the first valid entry
            if len(cata.transpose()) == 1:
                # Create first row with complete data including station info (last column contains station information)
                cata = np.mat([[lst[0]+'T'+lst[1], float(lst[3]), float(lst[4]), float(lst[5]), float(lst[2]), float(lst[6]), float(lst[5]), lst[-1]]])
            else:
                # Append new row with complete data to existing catalog
                cata = np.r_[cata, np.mat([[lst[0]+'T'+lst[1], float(lst[3]), float(lst[4]), float(lst[5]), float(lst[2]), float(lst[6]), float(lst[5]), lst[-1]]])]

# %% [markdown]
# ## Download info

# %%
# --- 0. Prep depth, latitude, and longitude lists for Moho interpolation ---
dplst = []
latlst = []
lonlst = []

# --- 1. Get station info
# Set time window for station search (1 hour period starting from 2010-01-01)
starttime = UTCDateTime('2010-01-01T00:00:00')
endtime = starttime + 3600

# Define geographic search parameters
station_search_lower_range=0  # Minimum search radius (0 degrees)
station_search_upper_range=1.0  # Maximum search radius (1 degree from target)

# Target coordinates for station search
search_lo = 91.127
search_la = 29.703

# Query IRIS database for station information; retrieves metadata and instrument response for stations matching criteria
inventory = client.get_stations(level='response',  # Get instrument response data
                               channel='BH*',      # Broadband horizontal channels
                               network="IC",       
                               location="00",      # Location code "00"
                               starttime=starttime,  # Start of time window
                               endtime=endtime,      # End of time window
                               latitude=search_la,   # Center latitude
                               longitude=search_lo,  # Center longitude
                               minradius=station_search_lower_range,  # Min search radius
                               maxradius=station_search_upper_range)  # Max search radius

# Display the found station information
print(inventory)

# Extract specific station metadata for later use
net = inventory[0]                # Network object (contains network-level metadata)
stn = inventory[0][0]             # Station object (contains station-level metadata)
stla = inventory[0][0].latitude   # Station latitude
stlo = inventory[0][0].longitude  # Station longitude

# --- 2. Find the corners for a study region
# Define anchor point (point1), rectangle dimensions, other parameters
anchor = (89.5, 25.8)  # Starting point
lat1 = anchor[1] * (math.pi / 180)  # Anchor latitude in radians
lon1 = anchor[0] * (math.pi / 180)  # Anchor longitude in radians
wd = 620  # Width of rectangle in kilometers
lt = 480  # Length of rectangle in kilometers
brng = 4*np.pi/180 # Bearing is 4 degrees converted to radians
R = 6378.1 # Radius of the Earth

# Calculate second corner point (point2): moving 'wd' km east from anchor point
lat2 = math.asin( math.sin(lat1)*math.cos(wd/R) +
             math.cos(lat1)*math.sin(wd/R)*math.cos(brng))
lon2 = lon1 + math.atan2(math.sin(brng)*math.sin(wd/R)*math.cos(lat1),
                     math.cos(wd/R)-math.sin(lat1)*math.sin(lat2))
point2 = (lon2*180/np.pi, lat2*180/np.pi)  # Convert back to degrees

# Calculate third corner point (point3) - moving 'lt' km north from anchor
lat3 = math.asin( math.sin(lat1)*math.cos(lt/R) +
             math.cos(lat1)*math.sin(lt/R)*math.cos(brng-np.pi/2))  # Subtract 90° (π/2) to go north
lon3 = lon1 + math.atan2(math.sin(brng-np.pi/2)*math.sin(lt/R)*math.cos(lat1),
                     math.cos(lt/R)-math.sin(lat1)*math.sin(lat2))
point3 = (lon3*180/np.pi, lat3*180/np.pi)  # Convert back to degrees

# Calculate fourth corner point (point4) - moving 'wd' km east from point3
lat1 = point3[1] * (math.pi / 180) # Reset lat1/lon1 to point3 coordinates
lon1 = point3[0] * (math.pi / 180)
lat4 = math.asin( math.sin(lat1)*math.cos(wd/R) +
             math.cos(lat1)*math.sin(wd/R)*math.cos(brng))
lon4 = lon1 + math.atan2(math.sin(brng)*math.sin(wd/R)*math.cos(lat1),
                     math.cos(wd/R)-math.sin(lat1)*math.sin(lat2))
point4 = (lon4*180/np.pi, lat4*180/np.pi)  # Convert back to degrees

# Form a path to select the earthquakes
p = Path([anchor, point2, point4, point3])

# --- 3. Select and process the earthquakes
mag_min = 3  # Minimum magnitude threshold for earthquake selection

# Open output files for writing selected earthquake data
# fw1 = open('selected.txt','w')        # File for earthquakes with station info
# fw2 = open('selected_for_search.txt','w')  # File with timestamps for data search
fw3 = open(name,'w')     # File with all regional earthquake info

# Loop through each earthquake in the catalog
for i in range(0,len(cata)):
    # Extract earthquake parameters from catalog
    evla = float(cata[i,1])  # Event latitude
    evlo = float(cata[i,2])  # Event longitude  
    evdp = float(cata[i,3])  # Event depth
    mag = float(cata[i,4])   # Event magnitude
    dperr = float(cata[i,5]) # Depth error
    dpmin = float(cata[i,6]) # Minimum depth
    star = cata[i,7] # Star flag
    star = star[0]
    if star == '*':
        star = '*'
    else:
        star = '-'
    
    # Check if earthquake is within study region AND meets magnitude threshold
    if p.contains_points([(evlo,evla)]) and mag >= mag_min:
        
        # # Write earthquake info to output files
        # if cata[i,-1] != '--':  # If station info exists
        #     fw1.write(str(UTCDateTime(cata[i,0]))+' '+str(evla)+' '+str(evlo) + '   ' +str(evdp)+'   '+ cata[i,-1]+'\n')
        #     fw2.write('\''+str(UTCDateTime(cata[i,0]))+'\',\n')
        fw3.write(str(UTCDateTime(cata[i,0]))+'  '+str(evla)+'  '+str(evlo) + '  ' +str(evdp)+'  '+ str(mag)+'  '+ str(dperr)+'  ' + str(star)+'\n')
        dplst.append(evdp)
        latlst.append(evla)
        lonlst.append(evlo)
        
        # Set up time window for data download
        starttime = UTCDateTime(cata[i,0])
        endtime = UTCDateTime(cata[i,0]) + 3600 
        origin_time = starttime
        
        # Extract time components for filename construction
        yr = origin_time.year
        jd = origin_time.julday
        hr = origin_time.hour
        mins = origin_time.minute
        sec = origin_time.second
        msec = origin_time.microsecond
        
        # Calculate distance and azimuth from station to earthquake
        geo = gps2dist_azimuth(stla, stlo, evla, evlo)
        epi_dist = geo[0] / 1000  # Epicentral distance in km
        if epi_dist < 250:  # Skip if too close to station
            print('!!WARNING: Too close to station ' + cata[i,0].split("T")[0])
            continue
        baz = geo[1]  # Back azimuth
        gcarc = kilometer2degrees(epi_dist)  # Convert distance to degrees
        
        # Calculate P-wave arrival time using travel time model
        arrival = model.get_travel_times(source_depth_in_km=evdp, distance_in_degree=gcarc,
                                         phase_list=['p','P'])
        P_arrival_time_at_stn = origin_time + arrival[0].time  # Add travel time to origin time

        # Define time window around P arrival for data download
        seconds_before_P = P_arrival_time_at_stn - 60   # 60 seconds before P arrival
        seconds_after_P = P_arrival_time_at_stn + 400   # 400 seconds after P arrival
        
        # Print event information
        print('P Arrival time for event ' + cata[i,0].split("T")[0] + ' M' + str(mag)+' is: ' + str(P_arrival_time_at_stn))
        print('Origin time for this event: ' + str(arrival[0].time))
        print('Event latitude: ' + str(evla) + '  Event longitude: ' + str(evlo))
        
        # Download waveform data from IRIS
        try:
            stream = client.get_waveforms(net.code, stn.code, '00', 'BH*', seconds_before_P, seconds_after_P, attach_response=True)
        except:
            print('!!WARNING: No data for event ' + cata[i,0].split("T")[0])
            continue
            
        # Check data quality
        number_of_traces = len(stream)
        number_of_locs = int(len(stream) / 3)
        print(str(number_of_traces) + ' traces found for event ' + cata[i,0].split("T")[0])
        if number_of_traces > 3:  # Skip if data is fragmented
            print('!!WARNING: Fragmented data')
            continue
            
        # Rename (and rotate if uncomment)
        stream[0].stats.channel = 'BHN'  # Rename channels, works for LSA in particular
        stream[1].stats.channel = 'BHE'
        stream[2].stats.channel = 'BHZ'
        # result = gps2dist_azimuth(stla, stlo, evla, evlo, a=6378137.0, f=0.0033528106647474805)
        # a0 = max(stream[1].data)  # Store original amplitude for comparison
        # stream.rotate(method = 'NE->RT',back_azimuth = result[1])
        
        # # Check if rotation was successful
        # if abs(max(stream[1].data) - a0)/a0 < 0.01:
        #     print('!!WARNING: Traces might not be rotated')
            
        # Write raw data to SAC files
        for tr in stream:
            loc = tr.stats.location
            chan = tr.stats.channel

            # Construct SAC filename with event and station info
            date_str = str(origin_time)
            sacnm = raw_directory + '/' + net.code + '.' + stn.code + '.' + str(loc) + '.' + date_str + '.' + chan + '.SAC'
            print('(Raw) Event written to SAC file: ' + sacnm)
            
            # Convert ObsPy trace to SAC format
            sac = SACTrace.from_obspy_trace(tr)
            sac.kcmpnm = chan      # Component name
            sac.gcarc = gcarc      # Great circle distance
            sac.baz = baz          # Back azimuth
            sac.evlo = evlo        # Event longitude
            sac.evla = evla        # Event latitude
            sac.stlo = stlo        # Station longitude
            sac.stla = stla        # Station latitude
            sac.evdp = evdp        # Event depth
            sac.user0 = dperr      # Depth error
            sac.user1 = dpmin      # Minimum depth
            
            # Assign catalog source code to user3 field
            if cata[i,-1] == '*Alvizuri': sac.user3 = 1
            elif cata[i,-1] == '*Craig': sac.user3 = 2
            elif cata[i,-1] == '*Baur': sac.user3 = 3
            elif cata[i,-1] == '*Parija': sac.user3 = 4
            elif cata[i,-1] == '*Michailos': sac.user3 = 5
            elif cata[i,-1] == '*GANSSER': sac.user3 = 6
            elif cata[i,-1] == '*Monsalve': sac.user3 = 7
            elif cata[i,-1] == '*Jiang': sac.user3 = 8
            elif cata[i,-1] == '*gmt': sac.user3 = 9
            elif cata[i,-1] == '*isc': sac.user3 = 10
            else: sac.user3 = 0
            
            sac.mag = mag          # Magnitude
            sac.a = P_arrival_time_at_stn  # P arrival time
            sac.o = origin_time    # Origin time
            sac.write(sacnm)       # Write SAC file

print('Done!')
# fw1.close()
# fw2.close()
fw3.close()
# Out:
# Inventory created at 2025-08-18T18:34:17.390500Z
# 	Created by: IRIS WEB SERVICE: fdsnws-station | version: 1.1.52
# 		    http://service.iris.edu/fdsnws/station/1/query?starttime=2010-01-01...
# 	Sending institution: IRIS-DMC (IRIS-DMC)
# 	Contains:
# 		Networks (1):
# 			IC
# 		Stations (1):
# 			IC.LSA (Tibet, China)
# 		Channels (3):
# 			IC.LSA.00.BHZ, IC.LSA.00.BHN, IC.LSA.00.BHE
# P Arrival time for event 2022-05-21 M4.2 is: 2022-05-21T02:46:14.383889Z
# Origin time for this event: 65.16088936461901
# Event latitude: 28.2186  Event longitude: 86.2888
# !!WARNING: No data for event 2022-05-21
# P Arrival time for event 2021-12-08 M4.2 is: 2021-12-08T04:24:16.478729Z
# Origin time for this event: 51.45472906470618
# Event latitude: 28.8093  Event longitude: 87.5826
# !!WARNING: No data for event 2021-12-08
# P Arrival time for event 2021-02-09 M4.3 is: 2021-02-09T01:51:00.603374Z
# Origin time for this event: 53.3963736288688
# Event latitude: 28.0331  Event longitude: 87.8568
# 3 traces found for event 2021-02-09
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2021-02-09T01:50:07.207000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2021-02-09T01:50:07.207000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2021-02-09T01:50:07.207000Z.BHZ.SAC
# P Arrival time for event 2021-01-11 M4.1 is: 2021-01-11T14:00:43.325715Z
# Origin time for this event: 54.0907147164412
# Event latitude: 28.028  Event longitude: 87.7888
# 3 traces found for event 2021-01-11
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2021-01-11T13:59:49.235000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2021-01-11T13:59:49.235000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2021-01-11T13:59:49.235000Z.BHZ.SAC
# P Arrival time for event 2019-11-27 M4.4 is: 2019-11-27T00:19:22.034206Z
# Origin time for this event: 49.61220641141033
# Event latitude: 28.1658  Event longitude: 87.8728
# 3 traces found for event 2019-11-27
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2019-11-27T00:18:32.422000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2019-11-27T00:18:32.422000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2019-11-27T00:18:32.422000Z.BHZ.SAC
# P Arrival time for event 2019-06-17 M4.6 is: 2019-06-17T17:59:15.514720Z
# Origin time for this event: 54.91972033267789
# Event latitude: 28.4217  Event longitude: 87.173
# 3 traces found for event 2019-06-17
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2019-06-17T17:58:20.595000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2019-06-17T17:58:20.595000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2019-06-17T17:58:20.595000Z.BHZ.SAC
# P Arrival time for event 2018-06-20 M4.4 is: 2018-06-20T04:16:25.137792Z
# Origin time for this event: 58.72779233678838
# Event latitude: 27.1508  Event longitude: 87.8133
# 3 traces found for event 2018-06-20
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2018-06-20T04:15:26.410000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2018-06-20T04:15:26.410000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2018-06-20T04:15:26.410000Z.BHZ.SAC
# P Arrival time for event 2018-06-20 M4.4 is: 2018-06-20T04:10:04.165209Z
# Origin time for this event: 64.28520921120585
# Event latitude: 26.9633  Event longitude: 87.505
# 3 traces found for event 2018-06-20
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2018-06-20T04:08:59.880000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2018-06-20T04:08:59.880000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2018-06-20T04:08:59.880000Z.BHZ.SAC
# P Arrival time for event 2018-06-17 M4.4 is: 2018-06-17T15:08:28.306342Z
# Origin time for this event: 51.1763424934016
# Event latitude: 27.4201  Event longitude: 88.4739
# 3 traces found for event 2018-06-17
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2018-06-17T15:07:37.130000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2018-06-17T15:07:37.130000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2018-06-17T15:07:37.130000Z.BHZ.SAC
# P Arrival time for event 2018-05-08 M4.0 is: 2018-05-08T13:08:37.710142Z
# Origin time for this event: 57.76014172591988
# Event latitude: 28.0604  Event longitude: 87.4282
# 3 traces found for event 2018-05-08
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2018-05-08T13:07:39.950000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2018-05-08T13:07:39.950000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2018-05-08T13:07:39.950000Z.BHZ.SAC
# P Arrival time for event 2016-11-27 M5.24 is: 2016-11-27T23:36:31.744034Z
# Origin time for this event: 70.7240341010173
# Event latitude: 27.35  Event longitude: 86.53
# 3 traces found for event 2016-11-27
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2016-11-27T23:35:21.020000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2016-11-27T23:35:21.020000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2016-11-27T23:35:21.020000Z.BHZ.SAC
# P Arrival time for event 2016-10-01 M4.2 is: 2016-10-01T11:36:49.785036Z
# Origin time for this event: 48.21503585906708
# Event latitude: 30.9806  Event longitude: 88.1037
# 3 traces found for event 2016-10-01
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2016-10-01T11:36:01.570000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2016-10-01T11:36:01.570000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2016-10-01T11:36:01.570000Z.BHZ.SAC
# P Arrival time for event 2016-05-09 M4.2 is: 2016-05-09T05:19:08.235549Z
# Origin time for this event: 73.4855492736657
# Event latitude: 28.21  Event longitude: 85.7631
# 3 traces found for event 2016-05-09
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2016-05-09T05:17:54.750000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2016-05-09T05:17:54.750000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2016-05-09T05:17:54.750000Z.BHZ.SAC
# P Arrival time for event 2016-04-19 M4.3 is: 2016-04-19T17:23:07.611545Z
# Origin time for this event: 49.70154494621552
# Event latitude: 28.3381  Event longitude: 87.8381
# 3 traces found for event 2016-04-19
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2016-04-19T17:22:17.910000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2016-04-19T17:22:17.910000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2016-04-19T17:22:17.910000Z.BHZ.SAC
# P Arrival time for event 2016-02-13 M3.7 is: 2016-02-13T21:38:44.034875Z
# Origin time for this event: 49.95487537297715
# Event latitude: 27.0268  Event longitude: 89.1875
# !!WARNING: No data for event 2016-02-13
# P Arrival time for event 2016-02-09 M4.7 is: 2016-02-09T02:30:10.832519Z
# Origin time for this event: 66.79251862671879
# Event latitude: 30.8319  Event longitude: 86.284
# !!WARNING: No data for event 2016-02-09
# P Arrival time for event 2015-10-10 M4.3 is: 2015-10-10T01:49:35.933491Z
# Origin time for this event: 50.36349065806213
# Event latitude: 27.2548  Event longitude: 88.8009
# 3 traces found for event 2015-10-10
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2015-10-10T01:48:45.570000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2015-10-10T01:48:45.570000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2015-10-10T01:48:45.570000Z.BHZ.SAC
# P Arrival time for event 2015-10-07 M4.2 is: 2015-10-07T04:59:45.426802Z
# Origin time for this event: 84.87680189778575
# Event latitude: 27.8771  Event longitude: 84.8817
# 3 traces found for event 2015-10-07
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2015-10-07T04:58:20.550000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2015-10-07T04:58:20.550000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2015-10-07T04:58:20.550000Z.BHZ.SAC
# P Arrival time for event 2015-08-01 M4.4 is: 2015-08-01T12:15:20.227468Z
# Origin time for this event: 51.66746760449618
# Event latitude: 28.7475  Event longitude: 87.6636
# 3 traces found for event 2015-08-01
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2015-08-01T12:14:28.560000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2015-08-01T12:14:28.560000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2015-08-01T12:14:28.560000Z.BHZ.SAC
# P Arrival time for event 2015-05-25 M4.3 is: 2015-05-25T10:46:59.000195Z
# Origin time for this event: 55.940194689513355
# Event latitude: 28.5718  Event longitude: 87.2411
# 3 traces found for event 2015-05-25
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2015-05-25T10:46:03.060000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2015-05-25T10:46:03.060000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2015-05-25T10:46:03.060000Z.BHZ.SAC
# P Arrival time for event 2015-04-25 M4.5 is: 2015-04-25T17:47:27.913539Z
# Origin time for this event: 70.32353893526769
# Event latitude: 28.2139  Event longitude: 86.1072
# 3 traces found for event 2015-04-25
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2015-04-25T17:46:17.590000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2015-04-25T17:46:17.590000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2015-04-25T17:46:17.590000Z.BHZ.SAC
# P Arrival time for event 2015-04-02 M4.6 is: 2015-04-02T00:57:42.923553Z
# Origin time for this event: 63.96355285384855
# Event latitude: 28.7007  Event longitude: 86.3309
# 3 traces found for event 2015-04-02
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2015-04-02T00:56:38.960000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2015-04-02T00:56:38.960000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2015-04-02T00:56:38.960000Z.BHZ.SAC
# P Arrival time for event 2014-12-26 M4.9 is: 2014-12-26T07:09:03.234024Z
# Origin time for this event: 53.644023678098826
# Event latitude: 28.5278  Event longitude: 87.3541
# 3 traces found for event 2014-12-26
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2014-12-26T07:08:09.590000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2014-12-26T07:08:09.590000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2014-12-26T07:08:09.590000Z.BHZ.SAC
# P Arrival time for event 2014-12-18 M4.96 is: 2014-12-18T15:33:23.318499Z
# Origin time for this event: 70.36849931176567
# Event latitude: 27.46  Event longitude: 86.56
# 3 traces found for event 2014-12-18
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2014-12-18T15:32:12.950000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2014-12-18T15:32:12.950000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2014-12-18T15:32:12.950000Z.BHZ.SAC
# P Arrival time for event 2014-08-22 M4.4 is: 2014-08-22T16:00:25.498951Z
# Origin time for this event: 48.24495147968046
# Event latitude: 28.159  Event longitude: 87.977
# 3 traces found for event 2014-08-22
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2014-08-22T15:59:37.254000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2014-08-22T15:59:37.254000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2014-08-22T15:59:37.254000Z.BHZ.SAC
# P Arrival time for event 2013-12-08 M4.0 is: 2013-12-08T14:20:39.859222Z
# Origin time for this event: 56.829222324942016
# Event latitude: 27.7317  Event longitude: 87.6012
# 3 traces found for event 2013-12-08
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2013-12-08T14:19:43.030000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2013-12-08T14:19:43.030000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2013-12-08T14:19:43.030000Z.BHZ.SAC
# P Arrival time for event 2013-08-30 M4.1 is: 2013-08-30T18:03:42.453874Z
# Origin time for this event: 73.6338744387823
# Event latitude: 28.0742  Event longitude: 85.7479
# 3 traces found for event 2013-08-30
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2013-08-30T18:02:28.820000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2013-08-30T18:02:28.820000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2013-08-30T18:02:28.820000Z.BHZ.SAC
# P Arrival time for event 2013-08-30 M4.9 is: 2013-08-30T17:49:53.883781Z
# Origin time for this event: 70.90378063743765
# Event latitude: 28.1613  Event longitude: 85.8966
# 3 traces found for event 2013-08-30
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2013-08-30T17:48:42.980000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2013-08-30T17:48:42.980000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2013-08-30T17:48:42.980000Z.BHZ.SAC
# P Arrival time for event 2013-08-04 M4.3 is: 2013-08-04T23:15:09.391275Z
# Origin time for this event: 59.23127470964487
# Event latitude: 28.2703  Event longitude: 87.1352
# 3 traces found for event 2013-08-04
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2013-08-04T23:14:10.160000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2013-08-04T23:14:10.160000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2013-08-04T23:14:10.160000Z.BHZ.SAC
# P Arrival time for event 2013-07-15 M4.7 is: 2013-07-15T19:40:36.260380Z
# Origin time for this event: 52.20038021673611
# Event latitude: 28.383  Event longitude: 87.599
# 3 traces found for event 2013-07-15
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2013-07-15T19:39:44.060000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2013-07-15T19:39:44.060000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2013-07-15T19:39:44.060000Z.BHZ.SAC
# P Arrival time for event 2013-04-19 M4.2 is: 2013-04-19T06:36:50.340101Z
# Origin time for this event: 57.37010110200082
# Event latitude: 27.333  Event longitude: 87.853
# 3 traces found for event 2013-04-19
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2013-04-19T06:35:52.970000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2013-04-19T06:35:52.970000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2013-04-19T06:35:52.970000Z.BHZ.SAC
# P Arrival time for event 2013-04-06 M4.6 is: 2013-04-06T18:37:29.674084Z
# Origin time for this event: 45.42408442125863
# Event latitude: 30.039  Event longitude: 88.051
# 3 traces found for event 2013-04-06
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2013-04-06T18:36:44.250000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2013-04-06T18:36:44.250000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2013-04-06T18:36:44.250000Z.BHZ.SAC
# P Arrival time for event 2012-12-21 M4.2 is: 2012-12-21T02:24:31.650849Z
# Origin time for this event: 42.290848748885985
# Event latitude: 28.567  Event longitude: 88.536
# !!WARNING: No data for event 2012-12-21
# P Arrival time for event 2012-11-05 M4.5 is: 2012-11-05T13:09:05.317362Z
# Origin time for this event: 65.28736156152401
# Event latitude: 28.447  Event longitude: 86.187
# 3 traces found for event 2012-11-05
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2012-11-05T13:08:00.030000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2012-11-05T13:08:00.030000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2012-11-05T13:08:00.030000Z.BHZ.SAC
# P Arrival time for event 2012-09-18 M4.6 is: 2012-09-18T12:27:16.625730Z
# Origin time for this event: 51.345729765910946
# Event latitude: 27.33  Event longitude: 88.642
# 3 traces found for event 2012-09-18
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2012-09-18T12:26:25.280000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2012-09-18T12:26:25.280000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2012-09-18T12:26:25.280000Z.BHZ.SAC
# P Arrival time for event 2012-08-09 M4.7 is: 2012-08-09T13:13:04.265960Z
# Origin time for this event: 59.35596023159616
# Event latitude: 28.456  Event longitude: 86.74
# 3 traces found for event 2012-08-09
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2012-08-09T13:12:04.910000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2012-08-09T13:12:04.910000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2012-08-09T13:12:04.910000Z.BHZ.SAC
# P Arrival time for event 2012-06-11 M4.5 is: 2012-06-11T04:36:54.813034Z
# Origin time for this event: 54.85303371180847
# Event latitude: 27.306  Event longitude: 88.13
# 3 traces found for event 2012-06-11
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2012-06-11T04:35:59.960000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2012-06-11T04:35:59.960000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2012-06-11T04:35:59.960000Z.BHZ.SAC
# P Arrival time for event 2012-05-30 M4.3 is: 2012-05-30T01:55:28.194473Z
# Origin time for this event: 57.574473455674756
# Event latitude: 27.328  Event longitude: 87.974
# 3 traces found for event 2012-05-30
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2012-05-30T01:54:30.620000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2012-05-30T01:54:30.620000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2012-05-30T01:54:30.620000Z.BHZ.SAC
# P Arrival time for event 2011-12-14 M4.0 is: 2011-12-14T20:21:48.894683Z
# Origin time for this event: 55.0546833534474
# Event latitude: 27.504  Event longitude: 87.955
# 3 traces found for event 2011-12-14
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2011-12-14T20:20:53.840000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2011-12-14T20:20:53.840000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2011-12-14T20:20:53.840000Z.BHZ.SAC
# P Arrival time for event 2011-11-12 M4.2 is: 2011-11-12T23:48:18.233754Z
# Origin time for this event: 81.42375442163576
# Event latitude: 28.212  Event longitude: 84.93
# 3 traces found for event 2011-11-12
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2011-11-12T23:46:56.810000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2011-11-12T23:46:56.810000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2011-11-12T23:46:56.810000Z.BHZ.SAC
# P Arrival time for event 2011-09-18 M4.8 is: 2011-09-18T13:12:50.591630Z
# Origin time for this event: 50.24162967747994
# Event latitude: 27.52  Event longitude: 88.583
# 3 traces found for event 2011-09-18
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2011-09-18T13:12:00.350000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2011-09-18T13:12:00.350000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2011-09-18T13:12:00.350000Z.BHZ.SAC
# P Arrival time for event 2011-09-18 M6.9 is: 2011-09-18T12:41:44.168406Z
# Origin time for this event: 52.33840638223421
# Event latitude: 27.44  Event longitude: 88.35
# 3 traces found for event 2011-09-18
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2011-09-18T12:40:51.830000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2011-09-18T12:40:51.830000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2011-09-18T12:40:51.830000Z.BHZ.SAC
# P Arrival time for event 2011-08-11 M4.2 is: 2011-08-11T22:02:25.998455Z
# Origin time for this event: 58.7684550637747
# Event latitude: 30.092  Event longitude: 86.814
# 3 traces found for event 2011-08-11
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2011-08-11T22:01:27.230000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2011-08-11T22:01:27.230000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2011-08-11T22:01:27.230000Z.BHZ.SAC
# P Arrival time for event 2011-05-24 M4.5 is: 2011-05-24T12:53:14.169456Z
# Origin time for this event: 74.07945609784495
# Event latitude: 30.042  Event longitude: 85.391
# 3 traces found for event 2011-05-24
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2011-05-24T12:52:00.090000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2011-05-24T12:52:00.090000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2011-05-24T12:52:00.090000Z.BHZ.SAC
# !!WARNING: Too close to station 2011-04-24
# P Arrival time for event 2011-02-10 M4.0 is: 2011-02-10T03:52:39.680555Z
# Origin time for this event: 55.45055513594359
# Event latitude: 27.215  Event longitude: 88.211
# 3 traces found for event 2011-02-10
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2011-02-10T03:51:44.230000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2011-02-10T03:51:44.230000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2011-02-10T03:51:44.230000Z.BHZ.SAC
# P Arrival time for event 2010-10-18 M4.0 is: 2010-10-18T04:28:04.596596Z
# Origin time for this event: 73.32659564720977
# Event latitude: 28.492  Event longitude: 85.647
# 3 traces found for event 2010-10-18
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2010-10-18T04:26:51.270000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2010-10-18T04:26:51.270000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2010-10-18T04:26:51.270000Z.BHZ.SAC
# P Arrival time for event 2010-10-17 M5.21 is: 2010-10-17T20:12:30.099668Z
# Origin time for this event: 71.63966810896315
# Event latitude: 28.622  Event longitude: 85.684
# 3 traces found for event 2010-10-17
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2010-10-17T20:11:18.460000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2010-10-17T20:11:18.460000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2010-10-17T20:11:18.460000Z.BHZ.SAC
# P Arrival time for event 2010-07-10 M4.6 is: 2010-07-10T10:16:41.816383Z
# Origin time for this event: 56.626382619486286
# Event latitude: 29.318  Event longitude: 86.981
# 3 traces found for event 2010-07-10
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2010-07-10T10:15:45.190000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2010-07-10T10:15:45.190000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2010-07-10T10:15:45.190000Z.BHZ.SAC
# P Arrival time for event 2010-02-26 M5.12 is: 2010-02-26T04:43:38.566034Z
# Origin time for this event: 59.216033601418715
# Event latitude: 28.41  Event longitude: 86.77
# 3 traces found for event 2010-02-26
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2010-02-26T04:42:39.350000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2010-02-26T04:42:39.350000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2010-02-26T04:42:39.350000Z.BHZ.SAC
# P Arrival time for event 2009-11-07 M4.1 is: 2009-11-07T23:01:24.190321Z
# Origin time for this event: 51.95032081976351
# Event latitude: 26.922  Event longitude: 89.178
# 3 traces found for event 2009-11-07
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2009-11-07T23:00:32.240000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2009-11-07T23:00:32.240000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2009-11-07T23:00:32.240000Z.BHZ.SAC
# P Arrival time for event 2009-06-06 M4.94 is: 2009-06-06T09:45:42.804550Z
# Origin time for this event: 65.83455035563726
# Event latitude: 30.99  Event longitude: 86.43
# !!WARNING: No data for event 2009-06-06
# P Arrival time for event 2008-12-25 M4.8 is: 2008-12-25T00:27:27.932958Z
# Origin time for this event: 51.72295757866967
# Event latitude: 27.235  Event longitude: 88.631
# 3 traces found for event 2008-12-25
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2008-12-25T00:26:36.210000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2008-12-25T00:26:36.210000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2008-12-25T00:26:36.210000Z.BHZ.SAC
# P Arrival time for event 2008-09-19 M4.0 is: 2008-09-19T19:47:57.588638Z
# Origin time for this event: 59.6786378271749
# Event latitude: 28.579  Event longitude: 86.671
# 3 traces found for event 2008-09-19
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2008-09-19T19:46:57.910000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2008-09-19T19:46:57.910000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2008-09-19T19:46:57.910000Z.BHZ.SAC
# P Arrival time for event 2008-06-22 M3.7 is: 2008-06-22T18:15:59.938089Z
# Origin time for this event: 71.16808898174787
# Event latitude: 28.429  Event longitude: 85.681
# 3 traces found for event 2008-06-22
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2008-06-22T18:14:48.770000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2008-06-22T18:14:48.770000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2008-06-22T18:14:48.770000Z.BHZ.SAC
# P Arrival time for event 2008-04-01 M3.9 is: 2008-04-01T10:18:05.194453Z
# Origin time for this event: 56.26445260570915
# Event latitude: 28.516  Event longitude: 87.008
# 3 traces found for event 2008-04-01
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2008-04-01T10:17:08.930000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2008-04-01T10:17:08.930000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2008-04-01T10:17:08.930000Z.BHZ.SAC
# P Arrival time for event 2007-11-07 M3.7 is: 2007-11-07T01:31:24.066416Z
# Origin time for this event: 58.37641637227414
# Event latitude: 28.021  Event longitude: 87.036
# 3 traces found for event 2007-11-07
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2007-11-07T01:30:25.690000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2007-11-07T01:30:25.690000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2007-11-07T01:30:25.690000Z.BHZ.SAC
# P Arrival time for event 2007-09-01 M4.0 is: 2007-09-01T01:34:07.312936Z
# Origin time for this event: 51.21293570459795
# Event latitude: 27.853  Event longitude: 87.873
# 3 traces found for event 2007-09-01
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2007-09-01T01:33:16.100000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2007-09-01T01:33:16.100000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2007-09-01T01:33:16.100000Z.BHZ.SAC
# P Arrival time for event 2007-08-15 M4.0 is: 2007-08-15T02:59:40.230151Z
# Origin time for this event: 74.64015084792538
# Event latitude: 31.284  Event longitude: 85.346
# 3 traces found for event 2007-08-15
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2007-08-15T02:58:25.590000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2007-08-15T02:58:25.590000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2007-08-15T02:58:25.590000Z.BHZ.SAC
# P Arrival time for event 2007-08-03 M4.3 is: 2007-08-03T03:51:57.934699Z
# Origin time for this event: 65.2846988680499
# Event latitude: 27.196  Event longitude: 86.932
# 3 traces found for event 2007-08-03
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2007-08-03T03:50:52.650000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2007-08-03T03:50:52.650000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2007-08-03T03:50:52.650000Z.BHZ.SAC
# P Arrival time for event 2007-05-16 M4.0 is: 2007-05-16T04:18:27.364558Z
# Origin time for this event: 59.41455755309583
# Event latitude: 27.291  Event longitude: 87.851
# 3 traces found for event 2007-05-16
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2007-05-16T04:17:27.950000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2007-05-16T04:17:27.950000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2007-05-16T04:17:27.950000Z.BHZ.SAC
# P Arrival time for event 2007-04-17 M4.1 is: 2007-04-17T07:05:27.746100Z
# Origin time for this event: 49.70610022934291
# Event latitude: 28.262  Event longitude: 87.759
# 3 traces found for event 2007-04-17
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2007-04-17T07:04:38.040000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2007-04-17T07:04:38.040000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2007-04-17T07:04:38.040000Z.BHZ.SAC
# P Arrival time for event 2007-04-06 M3.7 is: 2007-04-06T03:46:43.921846Z
# Origin time for this event: 62.38184580798652
# Event latitude: 28.442  Event longitude: 86.462
# 3 traces found for event 2007-04-06
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2007-04-06T03:45:41.540000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2007-04-06T03:45:41.540000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2007-04-06T03:45:41.540000Z.BHZ.SAC
# P Arrival time for event 2007-02-06 M4.3 is: 2007-02-06T21:39:53.516732Z
# Origin time for this event: 54.176731751114765
# Event latitude: 27.913  Event longitude: 87.622
# 3 traces found for event 2007-02-06
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2007-02-06T21:38:59.340000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2007-02-06T21:38:59.340000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2007-02-06T21:38:59.340000Z.BHZ.SAC
# P Arrival time for event 2006-10-28 M3.5 is: 2006-10-28T10:59:02.626703Z
# Origin time for this event: 47.60670252899387
# Event latitude: 31.145  Event longitude: 87.981
# 3 traces found for event 2006-10-28
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2006-10-28T10:58:15.020000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2006-10-28T10:58:15.020000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2006-10-28T10:58:15.020000Z.BHZ.SAC
# P Arrival time for event 2006-04-11 M3.5 is: 2006-04-11T14:16:16.101549Z
# Origin time for this event: 55.32154921219508
# Event latitude: 28.14  Event longitude: 87.407
# 3 traces found for event 2006-04-11
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2006-04-11T14:15:20.780000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2006-04-11T14:15:20.780000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2006-04-11T14:15:20.780000Z.BHZ.SAC
# P Arrival time for event 2006-02-03 M4.74 is: 2006-02-03T01:58:59.807304Z
# Origin time for this event: 72.587303661701
# Event latitude: 26.94  Event longitude: 86.7
# 3 traces found for event 2006-02-03
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2006-02-03T01:57:47.220000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2006-02-03T01:57:47.220000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2006-02-03T01:57:47.220000Z.BHZ.SAC
# P Arrival time for event 2006-01-20 M4.6 is: 2006-01-20T06:13:46.803807Z
# Origin time for this event: 81.68380689059717
# Event latitude: 31.44  Event longitude: 85.01
# 3 traces found for event 2006-01-20
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2006-01-20T06:12:25.120000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2006-01-20T06:12:25.120000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2006-01-20T06:12:25.120000Z.BHZ.SAC
# P Arrival time for event 2005-12-25 M4.0 is: 2005-12-25T18:09:14.864292Z
# Origin time for this event: 67.23429217058249
# Event latitude: 28.576  Event longitude: 86.087
# 3 traces found for event 2005-12-25
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2005-12-25T18:08:07.630000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2005-12-25T18:08:07.630000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2005-12-25T18:08:07.630000Z.BHZ.SAC
# P Arrival time for event 2005-10-30 M3.9 is: 2005-10-30T08:30:59.092775Z
# Origin time for this event: 50.12277455663198
# Event latitude: 27.85  Event longitude: 87.993
# 3 traces found for event 2005-10-30
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2005-10-30T08:30:08.970000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2005-10-30T08:30:08.970000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2005-10-30T08:30:08.970000Z.BHZ.SAC
# P Arrival time for event 2005-08-28 M4.8 is: 2005-08-28T13:15:08.068854Z
# Origin time for this event: 59.79885444603347
# Event latitude: 27.636  Event longitude: 87.419
# 3 traces found for event 2005-08-28
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2005-08-28T13:14:08.270000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2005-08-28T13:14:08.270000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2005-08-28T13:14:08.270000Z.BHZ.SAC
# P Arrival time for event 2005-08-20 M4.89 is: 2005-08-20T12:51:38.708959Z
# Origin time for this event: 46.998959453170585
# Event latitude: 31.08  Event longitude: 88.09
# 3 traces found for event 2005-08-20
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2005-08-20T12:50:51.710000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2005-08-20T12:50:51.710000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2005-08-20T12:50:51.710000Z.BHZ.SAC
# P Arrival time for event 2005-06-14 M4.6 is: 2005-06-14T14:24:16.573414Z
# Origin time for this event: 58.103413918720406
# Event latitude: 27.205  Event longitude: 87.92
# 3 traces found for event 2005-06-14
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2005-06-14T14:23:18.470000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2005-06-14T14:23:18.470000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2005-06-14T14:23:18.470000Z.BHZ.SAC
# P Arrival time for event 2005-05-27 M3.5 is: 2005-05-27T22:13:32.241871Z
# Origin time for this event: 72.2118711888958
# Event latitude: 26.143  Event longitude: 87.211
# 3 traces found for event 2005-05-27
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2005-05-27T22:12:20.030000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2005-05-27T22:12:20.030000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2005-05-27T22:12:20.030000Z.BHZ.SAC
# P Arrival time for event 2005-05-11 M4.6 is: 2005-05-11T04:14:24.492829Z
# Origin time for this event: 77.60282899994434
# Event latitude: 30.6  Event longitude: 85.172
# 3 traces found for event 2005-05-11
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2005-05-11T04:13:06.890000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2005-05-11T04:13:06.890000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2005-05-11T04:13:06.890000Z.BHZ.SAC
# P Arrival time for event 2005-04-06 M3.6 is: 2005-04-06T22:25:46.260637Z
# Origin time for this event: 61.83063704883182
# Event latitude: 30.439  Event longitude: 86.346
# 3 traces found for event 2005-04-06
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2005-04-06T22:24:44.430000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2005-04-06T22:24:44.430000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2005-04-06T22:24:44.430000Z.BHZ.SAC
# P Arrival time for event 2005-03-26 M4.8 is: 2005-03-26T20:32:58.196624Z
# Origin time for this event: 49.19662386163728
# Event latitude: 28.21  Event longitude: 87.84
# 3 traces found for event 2005-03-26
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2005-03-26T20:32:09.000000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2005-03-26T20:32:09.000000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2005-03-26T20:32:09.000000Z.BHZ.SAC
# P Arrival time for event 2004-11-10 M4.0 is: 2004-11-10T04:22:05.823626Z
# Origin time for this event: 51.01362571479689
# Event latitude: 27.964617  Event longitude: 87.82083
# !!WARNING: No data for event 2004-11-10
# P Arrival time for event 2004-08-25 M4.4 is: 2004-08-25T18:51:53.918009Z
# Origin time for this event: 66.21800865447787
# Event latitude: 30.214  Event longitude: 86.066
# 3 traces found for event 2004-08-25
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2004-08-25T18:50:47.700000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2004-08-25T18:50:47.700000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2004-08-25T18:50:47.700000Z.BHZ.SAC
# P Arrival time for event 2004-08-21 M4.0 is: 2004-08-21T09:09:36.481222Z
# Origin time for this event: 44.111221771938204
# Event latitude: 29.887  Event longitude: 88.032
# 3 traces found for event 2004-08-21
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2004-08-21T09:08:52.370000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2004-08-21T09:08:52.370000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2004-08-21T09:08:52.370000Z.BHZ.SAC
# P Arrival time for event 2004-07-08 M4.2 is: 2004-07-08T21:50:46.663999Z
# Origin time for this event: 46.14399906865961
# Event latitude: 29.844  Event longitude: 87.997
# 3 traces found for event 2004-07-08
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2004-07-08T21:50:00.520000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2004-07-08T21:50:00.520000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2004-07-08T21:50:00.520000Z.BHZ.SAC
# P Arrival time for event 2004-06-26 M4.2 is: 2004-06-26T03:00:11.849879Z
# Origin time for this event: 43.30987875123617
# Event latitude: 30.038  Event longitude: 88.052
# 3 traces found for event 2004-06-26
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2004-06-26T02:59:28.540000Z.BHN.SAC
# ...
# Origin time for this event: 57.795224125340056
# Event latitude: 28.384  Event longitude: 86.96
# 3 traces found for event 2003-01-22
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2003-01-22T07:20:10.099999Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2003-01-22T07:20:10.099999Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2003-01-22T07:20:10.099999Z.BHZ.SAC
# P Arrival time for event 2003-02-06 M3.4 is: 2003-02-06T23:19:01.674965Z
# Origin time for this event: 51.26551273056196
# Event latitude: 27.872  Event longitude: 87.854
# 3 traces found for event 2003-02-06
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2003-02-06T23:18:10.409452Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2003-02-06T23:18:10.409452Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2003-02-06T23:18:10.409452Z.BHZ.SAC
# P Arrival time for event 2003-02-25 M3.6 is: 2003-02-25T01:47:39.488681Z
# Origin time for this event: 57.67481585308508
# Event latitude: 28.484  Event longitude: 86.947
# 3 traces found for event 2003-02-25
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2003-02-25T01:46:41.813865Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2003-02-25T01:46:41.813865Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2003-02-25T01:46:41.813865Z.BHZ.SAC
# P Arrival time for event 2003-02-26 M3.9 is: 2003-02-26T20:00:25.894177Z
# Origin time for this event: 62.89417672368309
# Event latitude: 28.347  Event longitude: 86.449
# 3 traces found for event 2003-02-26
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2003-02-26T19:59:23.000000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2003-02-26T19:59:23.000000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2003-02-26T19:59:23.000000Z.BHZ.SAC
# P Arrival time for event 2003-03-08 M3.6 is: 2003-03-08T02:55:50.854710Z
# Origin time for this event: 74.35470997224068
# Event latitude: 26.846  Event longitude: 86.184
# 3 traces found for event 2003-03-08
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2003-03-08T02:54:36.500000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2003-03-08T02:54:36.500000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2003-03-08T02:54:36.500000Z.BHZ.SAC
# P Arrival time for event 2003-03-18 M3.6 is: 2003-03-18T07:25:41.880577Z
# Origin time for this event: 50.45057841619393
# Event latitude: 27.841  Event longitude: 87.982
# 3 traces found for event 2003-03-18
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2003-03-18T07:24:51.429999Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2003-03-18T07:24:51.429999Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2003-03-18T07:24:51.429999Z.BHZ.SAC
# P Arrival time for event 2003-03-25 M3.5 is: 2003-03-25T01:28:17.889594Z
# Origin time for this event: 72.2954990478226
# Event latitude: 28.941  Event longitude: 85.409
# 3 traces found for event 2003-03-25
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2003-03-25T01:27:05.594095Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2003-03-25T01:27:05.594095Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2003-03-25T01:27:05.594095Z.BHZ.SAC
# P Arrival time for event 2003-04-17 M3.5 is: 2003-04-17T01:13:44.196357Z
# Origin time for this event: 66.76127956842491
# Event latitude: 27.096  Event longitude: 86.798
# 3 traces found for event 2003-04-17
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2003-04-17T01:12:37.435077Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2003-04-17T01:12:37.435077Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2003-04-17T01:12:37.435077Z.BHZ.SAC
# P Arrival time for event 2003-04-21 M3.4 is: 2003-04-21T12:57:50.634006Z
# Origin time for this event: 59.22284195060197
# Event latitude: 28.776  Event longitude: 86.643
# 3 traces found for event 2003-04-21
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2003-04-21T12:56:51.411164Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2003-04-21T12:56:51.411164Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2003-04-21T12:56:51.411164Z.BHZ.SAC
# P Arrival time for event 2003-04-26 M3.6 is: 2003-04-26T03:13:22.768614Z
# Origin time for this event: 69.66204138026256
# Event latitude: 28.504  Event longitude: 85.828
# 3 traces found for event 2003-04-26
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2003-04-26T03:12:13.106573Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2003-04-26T03:12:13.106573Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2003-04-26T03:12:13.106573Z.BHZ.SAC
# P Arrival time for event 2004-10-10 M3.3 is: 2004-10-10T11:49:38.926738Z
# Origin time for this event: 50.686737716922565
# Event latitude: 27.928491  Event longitude: 87.89538
# !!WARNING: No data for event 2004-10-10
# P Arrival time for event 2012-03-27 M5.0 is: 2012-03-27T23:41:55.257774Z
# Origin time for this event: 71.25777435297076
# Event latitude: 26.09  Event longitude: 87.76
# 3 traces found for event 2012-03-27
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2012-03-27T23:40:44.000000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2012-03-27T23:40:44.000000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2012-03-27T23:40:44.000000Z.BHZ.SAC
# !!WARNING: Too close to station 2013-01-22
# !!WARNING: Too close to station 2013-01-24
# P Arrival time for event 2013-02-05 M3.3 is: 2013-02-05T19:27:57.891736Z
# Origin time for this event: 49.104736486975135
# Event latitude: 27.699  Event longitude: 88.239
# 3 traces found for event 2013-02-05
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2013-02-05T19:27:08.787000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2013-02-05T19:27:08.787000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2013-02-05T19:27:08.787000Z.BHZ.SAC
# P Arrival time for event 2013-02-09 M3.5 is: 2013-02-09T18:08:40.159564Z
# Origin time for this event: 52.43856427622319
# Event latitude: 26.992  Event longitude: 89.148
# 3 traces found for event 2013-02-09
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2013-02-09T18:07:47.721000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2013-02-09T18:07:47.721000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2013-02-09T18:07:47.721000Z.BHZ.SAC
# P Arrival time for event 2013-03-07 M3.2 is: 2013-03-07T16:26:29.176437Z
# Origin time for this event: 51.98043684966691
# Event latitude: 27.457  Event longitude: 88.543
# 3 traces found for event 2013-03-07
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2013-03-07T16:25:37.196000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2013-03-07T16:25:37.196000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2013-03-07T16:25:37.196000Z.BHZ.SAC
# P Arrival time for event 2013-04-10 M3.2 is: 2013-04-10T19:32:31.554590Z
# Origin time for this event: 62.238590371354974
# Event latitude: 26.156  Event longitude: 89.075
# 3 traces found for event 2013-04-10
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2013-04-10T19:31:29.316000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2013-04-10T19:31:29.316000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2013-04-10T19:31:29.316000Z.BHZ.SAC
# P Arrival time for event 2013-06-27 M4.2 is: 2013-06-27T23:24:56.508530Z
# Origin time for this event: 48.880529719708086
# Event latitude: 27.197  Event longitude: 89.252
# 3 traces found for event 2013-06-27
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2013-06-27T23:24:07.628000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2013-06-27T23:24:07.628000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2013-06-27T23:24:07.628000Z.BHZ.SAC
# P Arrival time for event 2013-09-20 M3.2 is: 2013-09-20T22:33:25.761785Z
# Origin time for this event: 51.33178485998666
# Event latitude: 27.66  Event longitude: 88.301
# 3 traces found for event 2013-09-20
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2013-09-20T22:32:34.430000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2013-09-20T22:32:34.430000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2013-09-20T22:32:34.430000Z.BHZ.SAC
# P Arrival time for event 2014-03-18 M4.1 is: 2014-03-18T22:27:25.714985Z
# Origin time for this event: 49.90498549494795
# Event latitude: 28.338  Event longitude: 87.946
# 3 traces found for event 2014-03-18
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2014-03-18T22:26:35.810000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2014-03-18T22:26:35.810000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2014-03-18T22:26:35.810000Z.BHZ.SAC
# !!WARNING: Too close to station 2014-04-11
# P Arrival time for event 2014-05-02 M3.9 is: 2014-05-02T11:15:58.346415Z
# Origin time for this event: 52.48341472390571
# Event latitude: 27.558  Event longitude: 88.381
# 3 traces found for event 2014-05-02
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2014-05-02T11:15:05.863000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2014-05-02T11:15:05.863000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2014-05-02T11:15:05.863000Z.BHZ.SAC
# P Arrival time for event 2014-06-02 M3.5 is: 2014-06-02T06:13:26.186677Z
# Origin time for this event: 51.05167714263523
# Event latitude: 27.142  Event longitude: 89.129
# 3 traces found for event 2014-06-02
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2014-06-02T06:12:35.135000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2014-06-02T06:12:35.135000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2014-06-02T06:12:35.135000Z.BHZ.SAC
# P Arrival time for event 2014-07-04 M4.8 is: 2014-07-04T05:59:32.063912Z
# Origin time for this event: 49.898912418809964
# Event latitude: 27.87  Event longitude: 88.008
# 3 traces found for event 2014-07-04
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2014-07-04T05:58:42.165000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2014-07-04T05:58:42.165000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2014-07-04T05:58:42.165000Z.BHZ.SAC
# P Arrival time for event 2014-07-19 M3.8 is: 2014-07-19T06:40:47.654263Z
# Origin time for this event: 48.72626252485977
# Event latitude: 27.415  Event longitude: 88.811
# 3 traces found for event 2014-07-19
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2014-07-19T06:39:58.928000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2014-07-19T06:39:58.928000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2014-07-19T06:39:58.928000Z.BHZ.SAC
# P Arrival time for event 2014-07-28 M3.5 is: 2014-07-28T11:32:15.829840Z
# Origin time for this event: 51.5928402499331
# Event latitude: 28.014  Event longitude: 87.954
# 3 traces found for event 2014-07-28
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2014-07-28T11:31:24.237000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2014-07-28T11:31:24.237000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2014-07-28T11:31:24.237000Z.BHZ.SAC
# !!WARNING: Too close to station 2014-10-16
# P Arrival time for event 2014-10-29 M3.9 is: 2014-10-29T19:05:55.740952Z
# Origin time for this event: 51.8419523250776
# Event latitude: 27.214  Event longitude: 88.818
# 3 traces found for event 2014-10-29
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2014-10-29T19:05:03.899000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2014-10-29T19:05:03.899000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2014-10-29T19:05:03.899000Z.BHZ.SAC
# P Arrival time for event 2014-11-19 M3.9 is: 2014-11-19T17:28:17.970784Z
# Origin time for this event: 47.95578428911692
# Event latitude: 28.254  Event longitude: 87.947
# 3 traces found for event 2014-11-19
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2014-11-19T17:27:30.015000Z.BHN.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2014-11-19T17:27:30.015000Z.BHE.SAC
# (Raw) Event written to SAC file: /Users/emmanuelzheng/Downloads/Synthetics/Seiobs/ST_Raw_Data//IC.LSA.00.2014-11-19T17:27:30.015000Z.BHZ.SAC
# Done!

# %% [markdown]
# ## Append d-H values

# %%
# Open the Moho profile text file; read all lines from the file into a list of strings
fr1 = open('/Users/emmanuelzheng/Downloads/Synthetics/Xiaohan/Moho_RF_int.txt','r')
lines_r1 = fr1.readlines()

# Define the longitude grid from 74° to 110° with 145 points (0.25° spacing)
xmo = np.linspace(74, 110, 145)
# Define the latitude grid from 26° to 42° with 65 points (0.25° spacing)
ymo = np.linspace(26, 42, 65)
# Create 2D mesh grid arrays for the longitude and latitude coordinates
[xm, ym] = np.meshgrid(xmo,ymo)
# Initialize the Moho depth grid with zeros (shape 145 x 65, matching xmo x ymo)
zmo = np.zeros([145, 65])

# Loop over each line from the Moho file to populate the zmo grid
i = 0
for line in lines_r1:
    # Split the current line into whitespace-separated fields
    elements = line.split()
    # If the depth value (third column) is valid (< 10000), assign it into zmo
    if float(elements[2]) < 10000:
        zmo[i%145, i//145] = float(elements[2])
    # Otherwise, set a default/fallback value (e.g., 40 km) for missing/invalid entries
    else:
        zmo[i%145, i//145] = 40 #np.nan
    # Increment the flat index counter for the next line
    i = i + 1
# Transpose the Moho depth grid so its shape aligns with [len(ymo), len(xmo)]
zmo = zmo.transpose()

# Make a working copy of depth list (dplst) so original is not modified
d_h = dplst.copy()
# Build a 2D linear interpolator over the Moho grid (longitude xmo, latitude ymo, depth zmo)
f = interpolate.interp2d(xmo, ymo, zmo, kind='linear')

# Loop over all points for which we want to compute adjusted depths
for i in range(len(dplst)):
    # Compute nearest-grid indices for current point's lon/lat relative to xmo/ymo spacing
    ix = round((lonlst[i] - np.min(xmo))/0.25)
    iy = round((latlst[i] - np.min(ymo))/0.25)
    # Option A: subtract grid node depth (nearest-neighbor) — kept for reference
    #d-H[i] = dplst[i] - zmo[iy, ix]
    # Option B: subtract bilinearly interpolated Moho depth at the exact lon/lat
    d_h[i] = dplst[i] - f(lonlst[i], latlst[i])

# Path to the file you previously wrote (update as needed)
file_path = name
# Read existing rows
with open(file_path, "r") as f:
	rows = [ln.rstrip("\n") for ln in f if ln.strip()]
# Overwrite file with appended d_h column
with open(file_path, "w") as f:
	for i, row in enumerate(rows):
		f.write(f"{row}  {float(d_h[i])}\n")
# Out:
# /var/folders/1b/q38gzq296kvdfg7pyzwtv9q80000gn/T/ipykernel_1216/2739738522.py:33: DeprecationWarning: `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.14.0.
#
# For legacy code, nearly bug-for-bug compatible replacements are
# `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
# scattered 2D data.
#
# In new code, for regular grids use `RegularGridInterpolator` instead.
# For scattered data, prefer `LinearNDInterpolator` or
# `CloughTocher2DInterpolator`.
#
# For more details see
# `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   f = interpolate.interp2d(xmo, ymo, zmo, kind='linear')
# /var/folders/1b/q38gzq296kvdfg7pyzwtv9q80000gn/T/ipykernel_1216/2739738522.py:43: DeprecationWarning: `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.14.0.
#
# For legacy code, nearly bug-for-bug compatible replacements are
# `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
# scattered 2D data.
#
# In new code, for regular grids use `RegularGridInterpolator` instead.
# For scattered data, prefer `LinearNDInterpolator` or
# `CloughTocher2DInterpolator`.
#
# For more details see
# `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   d_h[i] = dplst[i] - f(lonlst[i], latlst[i])
